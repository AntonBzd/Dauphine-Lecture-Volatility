# %% [markdown]
# # Todo
#
# 1. Load the dataset for 1 date, explore the different metrics (strike distribution, number of calls vs puts, expiry available, forward curve, etc)
# 2. For a given several maturities 𝑇_1,𝑇_2,𝑒𝑡𝑐, plot the implied volatility with respect to strike 𝐾, moneyness 𝑚, delta Δ for both calls and puts.
# 3. For a chosen maturity 𝑇*1, and using the associated 𝑆*𝑡,𝐹*𝑡,𝜎*(𝑚𝑘𝑡,𝑖) calibrate a SABR model. More precisely use Hagan’s formula (2002) and minimize the $SSE=\sum_{option\ i}\left(\sigma_{mkt,i}-\sigma_{SABR,i}\right)$ or MSE using scipy.minimize. You can use a L-BFGS-B solver.
#    - Generalize to all the other smiles of this single day.
#    - Using the tools provided compute the Black & Scholes (1973) greeks and prices, compare with initial values.
# 4. Repeat 3. but for an SSVI model Gatheral & Jacquier (2014) to get all the surface at once.
# 5. Generalize 3 or 4 to multiple days, compute the realized volatility for different windows.
# 6. Using the rule-based selection function explore the implied volatility structure through time and strikes, vs realized, skew etc.

# %%
# Setup auto reload
# %load_ext autoreload
# %autoreload 2

# %%
import logging

logging.basicConfig(level=logging.INFO, format="%(asctime)s | %(levelname)s | %(message)s")

from warnings import filterwarnings

filterwarnings("ignore")

import pandas as pd
import numpy as np

from datetime import datetime
import matplotlib.pyplot as plt
import matplotlib

matplotlib.rc("font", **{"size": 22})

from investment_lab.option_selection import select_options
from investment_lab.metrics.volatility import rolling_realized_volatility
from investment_lab.metrics.util import levels_to_returns
from investment_lab.data.option_db import OptionLoader, SPYOptionLoader, extract_spot_from_options
from investment_lab.data.rates_db import USRatesLoader
from investment_lab.pricing.black_scholes import black_scholes_price, black_scholes_greeks
from investment_lab.pricing.implied_volatility import implied_volatility_vectorized
from investment_lab.rates import compute_forward
from investment_lab.metrics.distance import mse, sse
from investment_lab.surface.sabr import SABRSmoother
from investment_lab.surface.ssvi import SSVISmoother

# %%
df_options = OptionLoader.load_data(
    datetime(2022, 1, 4),
    datetime(2022, 1, 4),
    process_kwargs={"ticker": "AAPL"},
)
df_options.head()
# Out:
# 2026-04-03 09:11:16,153 | INFO | Reading between 2022-01-04 00:00:00 2022-01-04 00:00:00 from ..//data/optiondb_2016_2023.parquet with None
# 2026-04-03 09:12:50,642 | INFO | Processing with {'ticker': 'AAPL'}
# 2026-04-03 09:12:50,727 | INFO | Potentially add extra field with None
#           spot  strike expiration    delta    gamma     vega    theta  \
# 137425  179.72   105.0 2022-01-07  0.99760  0.00019  0.00119 -0.02392
# 137426  179.72   110.0 2022-01-07  0.99732  0.00022  0.00186 -0.02303
# 137427  179.72   115.0 2022-01-07  0.99724  0.00028  0.00164 -0.02307
# 137428  179.72   120.0 2022-01-07  0.99471  0.00054  0.00250 -0.04105
# 137429  179.72   125.0 2022-01-07  0.99422  0.00060  0.00349 -0.04125
#
#             rho  implied_volatility    bid    ask  volume call_put  \
# 137425  0.01073             1.96065  74.65  74.85     1.0        C
# 137426  0.01071             1.80137  69.65  69.85     0.0        C
# 137427  0.01166             1.65001  64.65  64.85     0.0        C
# 137428  0.01216             1.61633  59.60  59.95    10.0        C
# 137429  0.01248             1.46774  54.60  54.95     0.0        C
#
#                 option_id     mid ticker       date  day_to_expiration  \
# 137425  AAPL 20220107C105  74.750   AAPL 2022-01-04                  3
# 137426  AAPL 20220107C110  69.750   AAPL 2022-01-04                  3
# 137427  AAPL 20220107C115  64.750   AAPL 2022-01-04                  3
# 137428  AAPL 20220107C120  59.775   AAPL 2022-01-04                  3
# 137429  AAPL 20220107C125  54.775   AAPL 2022-01-04                  3
#
#         moneyness
# 137425   0.584242
# 137426   0.612063
# 137427   0.639884
# 137428   0.667705
# 137429   0.695526

# %%
df_spot = extract_spot_from_options(df_options)
df_spot.head()
# Out:
#         date    spot
# 0 2022-01-04  179.72

# %%
df_rates = USRatesLoader.load_data(datetime(2022, 1, 4), datetime(2022, 1, 4))
df_rates.head()
# Out:
# 2026-04-02 10:33:11,424 | INFO | Reading between 2022-01-04 00:00:00 2022-01-04 00:00:00 from ..//data/par-yield-curve-rates-2020-2023.csv with None
# 2026-04-02 10:33:11,551 | INFO | Processing with None
# 2026-04-02 10:33:11,552 | INFO | Potentially add extra field with None
#           date    1 Mo    2 Mo    3 Mo  4 Mo    6 Mo    1 Yr    2 Yr    3 Yr  \
# 503 2022-01-04  0.0006  0.0005  0.0008   NaN  0.0022  0.0038  0.0077  0.0102
#
#        5 Yr    7 Yr   10 Yr  20 Yr   30 Yr
# 503  0.0137  0.0157  0.0166  0.021  0.0207

# %%
df_options = compute_forward(df_options=df_options, df_rates=df_rates)
df_options.head()
# Out:
#      spot  strike expiration    delta    gamma     vega    theta      rho  \
# 0  179.72   105.0 2022-01-07  0.99760  0.00019  0.00119 -0.02392  0.01073
# 1  179.72   110.0 2022-01-07  0.99732  0.00022  0.00186 -0.02303  0.01071
# 2  179.72   115.0 2022-01-07  0.99724  0.00028  0.00164 -0.02307  0.01166
# 3  179.72   120.0 2022-01-07  0.99471  0.00054  0.00250 -0.04105  0.01216
# 4  179.72   125.0 2022-01-07  0.99422  0.00060  0.00349 -0.04125  0.01248
#
#    implied_volatility    bid  ...  volume  call_put          option_id  \
# 0             1.96065  74.65  ...     1.0         C  AAPL 20220107C105
# 1             1.80137  69.65  ...     0.0         C  AAPL 20220107C110
# 2             1.65001  64.65  ...     0.0         C  AAPL 20220107C115
# 3             1.61633  59.60  ...    10.0         C  AAPL 20220107C120
# 4             1.46774  54.60  ...     0.0         C  AAPL 20220107C125
#
#       mid  ticker       date day_to_expiration  moneyness  risk_free_rate  \
# 0  74.750    AAPL 2022-01-04                 3   0.584242          0.0006
# 1  69.750    AAPL 2022-01-04                 3   0.612063          0.0006
# 2  64.750    AAPL 2022-01-04                 3   0.639884          0.0006
# 3  59.775    AAPL 2022-01-04                 3   0.667705          0.0006
# 4  54.775    AAPL 2022-01-04                 3   0.695526          0.0006
#
#       forward
# 0  179.720886
# 1  179.720886
# 2  179.720886
# 3  179.720886
# 4  179.720886
#
# [5 rows x 21 columns]

# %%
df_single_expiry = df_options.loc[df_options.expiration == "2022-01-21"]
ax = df_single_expiry.pivot_table(index="strike", columns="call_put", values="implied_volatility").sort_index().plot()
ax.set_xlabel("strike")
ax.set_ylabel("Implied volatility")
ax.axvline(x=df_single_expiry["spot"].iloc[0], label="spot", color="black")

# %%
df_single_expiry = df_options.loc[df_options.expiration == "2022-01-21"]
ax = df_single_expiry.pivot_table(index="delta", columns="call_put", values="implied_volatility").sort_index().plot()
ax.set_xlabel("strike")
ax.set_ylabel("Implied volatility")
# ax.axvline(x=df_single_expiry['spot'].iloc[0],label="spot",color="black")
# Out:
# Text(0, 0.5, 'Implied volatility')

# %%
put_strike_filter = (df_single_expiry["call_put"] == "P") & (df_single_expiry["strike"] <= df_single_expiry["forward"])
call_strike_filter = (df_single_expiry["call_put"] == "C") & (df_single_expiry["strike"] >= df_single_expiry["forward"])

df_single_expiry_filtered = df_single_expiry.loc[put_strike_filter | call_strike_filter]


sabr_model = SABRSmoother(initial_params=(0.2, 0.75, -0.5, 0.2))
sabr_model = sabr_model.fit(
    df_single_expiry_filtered["forward"],
    df_single_expiry_filtered["strike"],
    df_single_expiry_filtered["day_to_expiration"] / 252,
    df_single_expiry_filtered["implied_volatility"],
)
df_single_expiry["implied_volatility_SABR"] = sabr_model.transform(
    df_single_expiry["forward"],
    df_single_expiry["strike"],
    df_single_expiry["day_to_expiration"] / 252,
)
df_single_expiry[["implied_volatility_SABR", "implied_volatility"]].head()
# Out:
# 2026-04-02 10:33:12,534 | INFO | Fitting SABR model on 102 records
# 2026-04-02 10:33:12,534 | INFO | Initial guess: (0.2, 0.75, -0.5, 0.2)
# 2026-04-02 10:33:12,534 | INFO | Parameter bounds: [(1e-06, None), (0, 1), (-0.999, 0.999), (1e-06, None)]
# 2026-04-02 10:33:12,541 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:33:14,143 | INFO | Successfully fitted SABR Model. Found the following Parameters [0.76316998 0.57881756 0.00742318 6.34622789]
#      implied_volatility_SABR  implied_volatility
# 196                 2.557076             2.56974
# 197                 2.453771             2.41264
# 198                 2.405261             2.35488
# 199                 2.358619             2.26471
# 200                 2.313700             2.20327

# %%
df_single_expiry[["implied_volatility_SABR", "implied_volatility"]].plot.scatter(x="implied_volatility", y="implied_volatility_SABR")
# Out:
# <Axes: xlabel='implied_volatility', ylabel='implied_volatility_SABR'>

# %%
ax = (
    df_single_expiry.pivot_table(index="strike", columns="call_put", values=["implied_volatility_SABR", "implied_volatility"])
    .sort_index()
    .plot(figsize=(20, 8))
)
ax.set_xlabel("strike")
ax.set_ylabel("Implied volatility")
# Out:
# Text(0, 0.5, 'Implied volatility')

# %%
put_strike_filter = (df_options["call_put"] == "P") & (df_options["strike"] <= df_options["forward"])
call_strike_filter = (df_options["call_put"] == "C") & (df_options["strike"] >= df_options["forward"])

df_options_filtered = df_options.loc[put_strike_filter | call_strike_filter]


ssvi_model = SSVISmoother(initial_params=(0.2, -0.4, 0.2, 0.4))  # sigma, rho, eta, lamb
ssvi_model = ssvi_model.fit(
    df_options_filtered["forward"],
    df_options_filtered["strike"],
    df_options_filtered["day_to_expiration"] / 252,
    df_options_filtered["implied_volatility"],
)
total_variance_SSVI = ssvi_model.transform(
    df_options["forward"],
    df_options["strike"],
    df_options["day_to_expiration"] / 252,
)
df_options["implied_volatility_SSVI"] = np.sqrt(total_variance_SSVI / (df_options["day_to_expiration"] / 252))
df_options[["implied_volatility_SSVI", "implied_volatility"]].head()
# Out:
# 2026-04-02 10:33:14,798 | INFO | Fitting SSVI model on 855 records
# 2026-04-02 10:33:14,799 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:33:14,800 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:33:14,800 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:33:14,939 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.26399107 -0.08829909  1.89348887  0.5       ]
#    implied_volatility_SSVI  implied_volatility
# 0                 1.173977             1.96065
# 1                 1.123520             1.80137
# 2                 1.073096             1.65001
# 3                 1.022496             1.61633
# 4                 0.971496             1.46774

# %%
df_options.expiration.unique()
# Out:
# <DatetimeArray>
# ['2022-01-07 00:00:00', '2022-01-14 00:00:00', '2022-01-21 00:00:00',
#  '2022-01-28 00:00:00', '2022-02-04 00:00:00', '2022-02-11 00:00:00',
#  '2022-02-18 00:00:00', '2022-03-18 00:00:00', '2022-04-14 00:00:00',
#  '2022-05-20 00:00:00', '2022-06-17 00:00:00', '2022-07-15 00:00:00',
#  '2022-09-16 00:00:00', '2023-01-20 00:00:00', '2023-03-17 00:00:00',
#  '2023-06-16 00:00:00', '2023-09-15 00:00:00', '2024-01-19 00:00:00']
# Length: 18, dtype: datetime64[ns]

# %%
ax = (
    df_options[df_options.expiration == "2022-01-14"]
    .pivot_table(index="strike", columns="call_put", values=["implied_volatility_SSVI", "implied_volatility"])
    .sort_index()
    .plot(figsize=(20, 8))
)
ax.set_xlabel("strike")
ax.set_ylabel("Implied volatility")
# Out:
# Text(0, 0.5, 'Implied volatility')

# %%
df_options.plot.scatter(x="implied_volatility", y="implied_volatility_SSVI")
# Out:
# <Axes: xlabel='implied_volatility', ylabel='implied_volatility_SSVI'>

# %% [markdown]
# ## 3D Surface

# %%
import scipy.interpolate as interp

df_options_copy = df_options.copy()
# df_options_copy = df_options_copy[df_options_copy["moneyness"].between(0.8, 1.2)]
# df_options_copy = df_options_copy[df_options_copy["day_to_expiration"].between(1, 365.25)]

put_strike_filter = (df_options_copy["call_put"] == "P") & (df_options_copy["strike"] <= df_options_copy["forward"])
call_strike_filter = (df_options_copy["call_put"] == "C") & (df_options_copy["strike"] >= df_options_copy["forward"])

df_options_copy = df_options_copy[put_strike_filter | call_strike_filter]

strikes = df_options_copy["strike"].values
expirations = df_options_copy["day_to_expiration"].values / 365.25
implied_volatility = df_options_copy["implied_volatility_SSVI"].values

# Create grid
strike_grid, exp_grid = np.meshgrid(np.linspace(strikes.min(), strikes.max(), 100), np.linspace(expirations.min(), expirations.max(), 100))

# Interpolate
vol_grid = interp.griddata((strikes, expirations), implied_volatility, (strike_grid, exp_grid), method="linear")

# Plot 3D surface
fig = plt.figure(figsize=(16, 10))
ax = fig.add_subplot(111, projection="3d")
ax.plot_surface(strike_grid, exp_grid, vol_grid, cmap="viridis", edgecolor="none")
ax.set_xlabel("Strike", fontsize=16)
ax.set_ylabel("Maturity (Years)", fontsize=16)
ax.set_zlabel("Implied Volatility", fontsize=16)
ax.set_title("Implied Volatility Surface Smoothed with SSVI Model (2022-01-04)", fontsize=18)
ax.view_init(elev=30, azim=60)  # Adjust azimuth and elevation as needed

# %% [markdown]
# # Reprice the dataset and see

# %%
df_options["mid_BS"] = black_scholes_price(
    S=df_options["spot"],
    K=df_options["strike"],
    option_type=df_options["call_put"],
    r=df_options["risk_free_rate"],
    T=df_options["day_to_expiration"] / 365.25,
    sigma=df_options["implied_volatility_SSVI"],
)
df_options[["delta_BS", "gamma_BS", "vega_BS", "theta_BS", "rho_BS"]] = black_scholes_greeks(
    S=df_options["spot"],
    K=df_options["strike"],
    option_type=df_options["call_put"],
    r=df_options["risk_free_rate"],
    T=df_options["day_to_expiration"] / 365.25,
    sigma=df_options["implied_volatility_SSVI"],
)
df_options.head()
# Out:
#      spot  strike expiration    delta    gamma     vega    theta      rho  \
# 0  179.72   105.0 2022-01-07  0.99760  0.00019  0.00119 -0.02392  0.01073
# 1  179.72   110.0 2022-01-07  0.99732  0.00022  0.00186 -0.02303  0.01071
# 2  179.72   115.0 2022-01-07  0.99724  0.00028  0.00164 -0.02307  0.01166
# 3  179.72   120.0 2022-01-07  0.99471  0.00054  0.00250 -0.04105  0.01216
# 4  179.72   125.0 2022-01-07  0.99422  0.00060  0.00349 -0.04125  0.01248
#
#    implied_volatility    bid  ...  moneyness  risk_free_rate     forward  \
# 0             1.96065  74.65  ...   0.584242          0.0006  179.720886
# 1             1.80137  69.65  ...   0.612063          0.0006  179.720886
# 2             1.65001  64.65  ...   0.639884          0.0006  179.720886
# 3             1.61633  59.60  ...   0.667705          0.0006  179.720886
# 4             1.46774  54.60  ...   0.695526          0.0006  179.720886
#
#   implied_volatility_SSVI     mid_BS  delta_BS      gamma_BS   vega_BS  \
# 0                1.173977  74.720518  1.000000  4.584370e-08  0.000014
# 1                1.123520  69.720544  0.999999  1.526250e-07  0.000045
# 2                1.073096  64.720573  0.999998  4.835202e-07  0.000138
# 3                1.022496  59.720610  0.999995  1.464587e-06  0.000397
# 4                0.971496  54.720670  0.999985  4.259874e-06  0.001098
#
#    theta_BS    rho_BS
# 0 -0.064020  0.862418
# 1 -0.069111  0.903485
# 2 -0.077991  0.944551
# 3 -0.096728  0.985613
# 4 -0.139927  1.026666
#
# [5 rows x 28 columns]

# %%
df_options[["delta_BS", "delta"]].hist(bins=100, figsize=(20, 8))
# Out:
# array([[<Axes: title={'center': 'delta_BS'}>,
#         <Axes: title={'center': 'delta'}>]], dtype=object)

# %%
fig, (ax, ax2, ax3) = plt.subplots(3, 2, figsize=(20, 22))

df_options.plot.scatter(
    x="mid", y="mid_BS", grid=True, c="day_to_expiration", cmap="viridis", ax=ax[0], title="Price", ylabel="Black Scholes", xlabel="Market"
)
df_options.plot.scatter(
    x="delta", y="delta_BS", grid=True, c="day_to_expiration", cmap="viridis", ax=ax[1], title="Delta", ylabel="Black Scholes", xlabel="Market"
)
df_options.plot.scatter(
    x="vega", y="vega_BS", grid=True, c="day_to_expiration", cmap="viridis", ax=ax2[0], title="Vega", ylabel="Black Scholes", xlabel="Market"
)
df_options.plot.scatter(
    x="gamma", y="gamma_BS", grid=True, c="day_to_expiration", cmap="viridis", ax=ax2[1], title="Gamma", ylabel="Black Scholes", xlabel="Market"
)
df_options.plot.scatter(
    x="theta", y="theta_BS", grid=True, c="day_to_expiration", cmap="viridis", ax=ax3[0], title="Theta", ylabel="Black Scholes", xlabel="Market"
)
df_options.plot.scatter(
    x="rho", y="rho_BS", grid=True, c="day_to_expiration", cmap="viridis", ax=ax3[1], title="Rho", ylabel="Black Scholes", xlabel="Market"
)
# Out:
# <Axes: title={'center': 'Rho'}, xlabel='Market', ylabel='Black Scholes'>

# %% [markdown]
# # Time Series Calibration

# %%
df_options = OptionLoader.load_data(
    datetime(2020, 1, 4),
    datetime(2020, 12, 4),
    process_kwargs={"ticker": "AAPL"},
)
print(df_options.shape)
df_options.head()
# Out:
# 2026-04-02 10:33:21,260 | INFO | Reading between 2020-01-04 00:00:00 2020-12-04 00:00:00 from ..//data/optiondb_2016_2023.parquet with None
# 2026-04-02 10:34:05,239 | INFO | Processing with {'ticker': 'AAPL'}
# 2026-04-02 10:34:05,328 | INFO | Potentially add extra field with None
# (545254, 19)
#          spot  strike expiration    delta    gamma     vega    theta      rho  \
# 169768  299.8   200.0 2020-01-10  1.00000  0.00000  0.00000 -0.00004  0.02788
# 169769  299.8   205.0 2020-01-10  0.99821  0.00015  0.00173 -0.01508  0.02786
# 169770  299.8   210.0 2020-01-10  0.99075  0.00057  0.00840 -0.08789  0.02864
# 169771  299.8   215.0 2020-01-10  0.99618  0.00028  0.00362 -0.03106  0.02948
# 169772  299.8   220.0 2020-01-10  1.00000  0.00000  0.00000 -0.00048  0.03037
#
#         implied_volatility    bid    ask  volume call_put          option_id  \
# 169768             0.00000  99.15  99.95     0.0        C  AAPL 20200110C200
# 169769             1.13225  94.56  95.05     2.0        C  AAPL 20200110C205
# 169770             1.32704  89.65  90.20     0.0        C  AAPL 20200110C210
# 169771             1.08562  84.70  84.95     5.0        C  AAPL 20200110C215
# 169772             0.00000  79.34  80.05     0.0        C  AAPL 20200110C220
#
#            mid ticker       date  day_to_expiration  moneyness
# 169768  99.550   AAPL 2020-01-06                  4   0.667111
# 169769  94.805   AAPL 2020-01-06                  4   0.683789
# 169770  89.925   AAPL 2020-01-06                  4   0.700467
# 169771  84.825   AAPL 2020-01-06                  4   0.717145
# 169772  79.695   AAPL 2020-01-06                  4   0.733823

# %%
df_rates = USRatesLoader.load_data(
    datetime(2020, 1, 4),
    datetime(2020, 12, 4),
)
df_options = compute_forward(df_options=df_options, df_rates=df_rates)
df_options.head()
# Out:
# 2026-04-02 10:34:11,790 | INFO | Reading between 2020-01-04 00:00:00 2020-12-04 00:00:00 from ..//data/par-yield-curve-rates-2020-2023.csv with None
# 2026-04-02 10:34:11,917 | INFO | Processing with None
# 2026-04-02 10:34:11,922 | INFO | Potentially add extra field with None
#     spot  strike expiration    delta    gamma     vega    theta      rho  \
# 0  299.8   200.0 2020-01-10  1.00000  0.00000  0.00000 -0.00004  0.02788
# 1  299.8   205.0 2020-01-10  0.99821  0.00015  0.00173 -0.01508  0.02786
# 2  299.8   210.0 2020-01-10  0.99075  0.00057  0.00840 -0.08789  0.02864
# 3  299.8   215.0 2020-01-10  0.99618  0.00028  0.00362 -0.03106  0.02948
# 4  299.8   220.0 2020-01-10  1.00000  0.00000  0.00000 -0.00048  0.03037
#
#    implied_volatility    bid  ...  volume  call_put          option_id  \
# 0             0.00000  99.15  ...     0.0         C  AAPL 20200110C200
# 1             1.13225  94.56  ...     2.0         C  AAPL 20200110C205
# 2             1.32704  89.65  ...     0.0         C  AAPL 20200110C210
# 3             1.08562  84.70  ...     5.0         C  AAPL 20200110C215
# 4             0.00000  79.34  ...     0.0         C  AAPL 20200110C220
#
#       mid  ticker       date day_to_expiration  moneyness  risk_free_rate  \
# 0  99.550    AAPL 2020-01-06                 4   0.667111          0.0154
# 1  94.805    AAPL 2020-01-06                 4   0.683789          0.0154
# 2  89.925    AAPL 2020-01-06                 4   0.700467          0.0154
# 3  84.825    AAPL 2020-01-06                 4   0.717145          0.0154
# 4  79.695    AAPL 2020-01-06                 4   0.733823          0.0154
#
#       forward
# 0  299.850566
# 1  299.850566
# 2  299.850566
# 3  299.850566
# 4  299.850566
#
# [5 rows x 21 columns]

# %%
def daily_vol_calibration(df_day_group: pd.DataFrame) -> pd.DataFrame:
    put_strike_filter = (df_day_group["call_put"] == "P") & (df_day_group["strike"] <= df_day_group["forward"])
    call_strike_filter = (df_day_group["call_put"] == "C") & (df_day_group["strike"] >= df_day_group["forward"])
    df_options_filtered = df_day_group.loc[put_strike_filter | call_strike_filter]

    ssvi_model = SSVISmoother(initial_params=(0.2, -0.4, 0.2, 0.4))  # sigma, rho, eta, lamb
    ssvi_model = ssvi_model.fit(
        df_options_filtered["forward"],
        df_options_filtered["strike"],
        df_options_filtered["day_to_expiration"] / 252,
        df_options_filtered["implied_volatility"],
    )
    total_variance_SSVI = ssvi_model.transform(
        df_day_group["forward"],
        df_day_group["strike"],
        df_day_group["day_to_expiration"] / 252,
    )
    df_day_group["implied_volatility_SSVI"] = np.sqrt(total_variance_SSVI / (df_day_group["day_to_expiration"] / 252))

    return df_day_group


df_options_calibrated = df_options.groupby("date").apply(daily_vol_calibration).reset_index(drop=True)
df_options_calibrated.head()
# Out:
# 2026-04-02 10:34:26,975 | INFO | Fitting SSVI model on 967 records
# 2026-04-02 10:34:26,976 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:26,977 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:26,978 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:27,038 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23383667 -0.17672501  1.33989481  0.5       ]
# 2026-04-02 10:34:27,043 | INFO | Fitting SSVI model on 975 records
# 2026-04-02 10:34:27,045 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:27,046 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:27,047 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:27,102 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23535328 -0.16406736  1.34121297  0.5       ]
# 2026-04-02 10:34:27,108 | INFO | Fitting SSVI model on 999 records
# 2026-04-02 10:34:27,109 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:27,110 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:27,111 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:27,187 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23570489 -0.14842178  1.3701619   0.5       ]
# 2026-04-02 10:34:27,191 | INFO | Fitting SSVI model on 1058 records
# 2026-04-02 10:34:27,192 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:27,192 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:27,193 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:27,270 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23849855 -0.11667324  1.40605531  0.5       ]
# 2026-04-02 10:34:27,275 | INFO | Fitting SSVI model on 1062 records
# 2026-04-02 10:34:27,276 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:27,277 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:27,278 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:27,356 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23918443 -0.11232669  1.39007437  0.5       ]
# 2026-04-02 10:34:27,361 | INFO | Fitting SSVI model on 1030 records
# 2026-04-02 10:34:27,362 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:27,362 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:27,363 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:27,438 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23899932 -0.09890675  1.41832042  0.5       ]
# 2026-04-02 10:34:27,443 | INFO | Fitting SSVI model on 1030 records
# 2026-04-02 10:34:27,443 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:27,444 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:27,444 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:27,520 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23835234 -0.09076518  1.45128759  0.5       ]
# 2026-04-02 10:34:27,523 | INFO | Fitting SSVI model on 1030 records
# 2026-04-02 10:34:27,524 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:27,525 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:27,526 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:27,592 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.24112293 -0.08928878  1.41719638  0.5       ]
# 2026-04-02 10:34:27,596 | INFO | Fitting SSVI model on 1030 records
# 2026-04-02 10:34:27,597 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:27,597 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:27,598 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:27,665 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.2383007  -0.08401705  1.48255484  0.5       ]
# 2026-04-02 10:34:27,672 | INFO | Fitting SSVI model on 1040 records
# 2026-04-02 10:34:27,673 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:27,673 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:27,674 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:27,740 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23541279 -0.09416992  1.49648863  0.5       ]
# 2026-04-02 10:34:27,745 | INFO | Fitting SSVI model on 976 records
# 2026-04-02 10:34:27,745 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:27,745 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:27,746 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:27,807 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23640499 -0.08372379  1.46944679  0.5       ]
# 2026-04-02 10:34:27,812 | INFO | Fitting SSVI model on 986 records
# 2026-04-02 10:34:27,812 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:27,813 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:27,813 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:27,875 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23487198 -0.09314473  1.47602508  0.5       ]
# 2026-04-02 10:34:27,880 | INFO | Fitting SSVI model on 1024 records
# 2026-04-02 10:34:27,882 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:27,885 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:27,886 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:27,979 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23233392 -0.08260974  1.54011341  0.5       ]
# 2026-04-02 10:34:27,985 | INFO | Fitting SSVI model on 1042 records
# 2026-04-02 10:34:27,986 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:27,986 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:27,987 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:28,060 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23607004 -0.08160992  1.50443965  0.5       ]
# 2026-04-02 10:34:28,068 | INFO | Fitting SSVI model on 974 records
# 2026-04-02 10:34:28,069 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:28,070 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:28,071 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:28,153 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.24299592 -0.10128542  1.42912229  0.5       ]
# 2026-04-02 10:34:28,159 | INFO | Fitting SSVI model on 974 records
# 2026-04-02 10:34:28,161 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:28,162 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:28,163 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:28,239 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23918089 -0.08889923  1.50904759  0.5       ]
# 2026-04-02 10:34:28,244 | INFO | Fitting SSVI model on 974 records
# 2026-04-02 10:34:28,245 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:28,246 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:28,248 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:28,323 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23635444 -0.07915214  1.51392382  0.5       ]
# 2026-04-02 10:34:28,326 | INFO | Fitting SSVI model on 1014 records
# 2026-04-02 10:34:28,328 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:28,329 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:28,330 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:28,389 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23624084 -0.09215015  1.52111974  0.5       ]
# 2026-04-02 10:34:28,393 | INFO | Fitting SSVI model on 1051 records
# 2026-04-02 10:34:28,394 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:28,395 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:28,396 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:28,494 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.24408634 -0.08216258  1.49645509  0.5       ]
# 2026-04-02 10:34:28,502 | INFO | Fitting SSVI model on 979 records
# 2026-04-02 10:34:28,502 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:28,504 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:28,505 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:28,586 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.24375109 -0.09992078  1.45363388  0.5       ]
# 2026-04-02 10:34:28,591 | INFO | Fitting SSVI model on 995 records
# 2026-04-02 10:34:28,592 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:28,592 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:28,593 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:28,670 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.24187043 -0.09261789  1.50613755  0.5       ]
# 2026-04-02 10:34:28,674 | INFO | Fitting SSVI model on 995 records
# 2026-04-02 10:34:28,675 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:28,676 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:28,677 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:28,743 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23961908 -0.07197125  1.56568836  0.5       ]
# 2026-04-02 10:34:28,748 | INFO | Fitting SSVI model on 1040 records
# 2026-04-02 10:34:28,751 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:28,751 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:28,752 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:28,811 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23785155 -0.07436333  1.54250835  0.5       ]
# 2026-04-02 10:34:28,819 | INFO | Fitting SSVI model on 1060 records
# 2026-04-02 10:34:28,819 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:28,820 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:28,821 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:28,890 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.24027066 -0.07998164  1.54160706  0.5       ]
# 2026-04-02 10:34:28,895 | INFO | Fitting SSVI model on 994 records
# 2026-04-02 10:34:28,896 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:28,896 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:28,898 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:29,076 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23986633 -0.08894288  1.53698301  0.5       ]
# 2026-04-02 10:34:29,084 | INFO | Fitting SSVI model on 997 records
# 2026-04-02 10:34:29,085 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:29,086 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:29,090 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:29,263 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.24139617 -0.08216638  1.517407    0.5       ]
# 2026-04-02 10:34:29,273 | INFO | Fitting SSVI model on 997 records
# 2026-04-02 10:34:29,273 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:29,274 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:29,275 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:29,374 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23672608 -0.07509012  1.5608126   0.5       ]
# 2026-04-02 10:34:29,380 | INFO | Fitting SSVI model on 1069 records
# 2026-04-02 10:34:29,381 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:29,384 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:29,384 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:29,508 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23888379 -0.07955788  1.48814121  0.5       ]
# 2026-04-02 10:34:29,514 | INFO | Fitting SSVI model on 1086 records
# 2026-04-02 10:34:29,514 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:29,517 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:29,517 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:29,641 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23395494 -0.07433536  1.56714276  0.5       ]
# 2026-04-02 10:34:29,647 | INFO | Fitting SSVI model on 1039 records
# 2026-04-02 10:34:29,648 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:29,651 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:29,651 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:29,761 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23836312 -0.08782904  1.50011204  0.5       ]
# 2026-04-02 10:34:29,769 | INFO | Fitting SSVI model on 1039 records
# 2026-04-02 10:34:29,770 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:29,771 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:29,771 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:29,942 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.23815213 -0.07984118  1.51409493  0.5       ]
# 2026-04-02 10:34:29,948 | INFO | Fitting SSVI model on 1039 records
# 2026-04-02 10:34:29,952 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:29,953 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:29,953 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:30,120 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.24024218 -0.08423536  1.49242387  0.5       ]
# 2026-04-02 10:34:30,123 | INFO | Fitting SSVI model on 1039 records
# 2026-04-02 10:34:30,123 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:30,130 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:30,131 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:30,242 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.24396103 -0.10475092  1.45549179  0.5       ]
# 2026-04-02 10:34:30,246 | INFO | Fitting SSVI model on 1010 records
# 2026-04-02 10:34:30,248 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:30,252 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:30,253 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:30,435 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.25583311 -0.13161078  1.37881403  0.5       ]
# 2026-04-02 10:34:30,450 | INFO | Fitting SSVI model on 1054 records
# 2026-04-02 10:34:30,450 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:30,450 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:30,450 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:30,567 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.26179781 -0.14830849  1.36548725  0.5       ]
# 2026-04-02 10:34:30,601 | INFO | Fitting SSVI model on 1054 records
# 2026-04-02 10:34:30,601 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:30,602 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:30,604 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:30,776 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.26089875 -0.15457888  1.34883661  0.5       ]
# 2026-04-02 10:34:30,795 | INFO | Fitting SSVI model on 1096 records
# 2026-04-02 10:34:30,796 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:30,797 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:30,801 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:30,975 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.27525087 -0.16351207  1.28629174  0.5       ]
# 2026-04-02 10:34:30,984 | INFO | Fitting SSVI model on 1096 records
# 2026-04-02 10:34:30,984 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:30,988 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:30,988 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:31,284 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.29444589 -0.23654085  1.3029791   0.5       ]
# 2026-04-02 10:34:31,292 | INFO | Fitting SSVI model on 1111 records
# 2026-04-02 10:34:31,292 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:31,292 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:31,292 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:31,442 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.26441568 -0.18489876  1.51536248  0.5       ]
# 2026-04-02 10:34:31,450 | INFO | Fitting SSVI model on 1111 records
# 2026-04-02 10:34:31,462 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:31,467 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:31,467 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:31,606 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.27969023 -0.2053858   1.46173816  0.5       ]
# 2026-04-02 10:34:31,617 | INFO | Fitting SSVI model on 1111 records
# 2026-04-02 10:34:31,617 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:31,617 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:31,617 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:31,738 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.2691019  -0.19801346  1.49843864  0.5       ]
# 2026-04-02 10:34:31,746 | INFO | Fitting SSVI model on 1146 records
# 2026-04-02 10:34:31,748 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:31,751 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:31,753 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:31,919 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.28763694 -0.21711999  1.47734363  0.5       ]
# 2026-04-02 10:34:31,929 | INFO | Fitting SSVI model on 1179 records
# 2026-04-02 10:34:31,929 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:31,934 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:31,935 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:32,061 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.29527623 -0.2622412   1.54565911  0.5       ]
# 2026-04-02 10:34:32,071 | INFO | Fitting SSVI model on 1125 records
# 2026-04-02 10:34:32,074 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:32,075 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:32,076 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:32,221 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.33370659 -0.31567031  1.45156681  0.5       ]
# 2026-04-02 10:34:32,229 | INFO | Fitting SSVI model on 1125 records
# 2026-04-02 10:34:32,231 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:32,231 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:32,234 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:32,381 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30796616 -0.3295209   1.53231157  0.5       ]
# 2026-04-02 10:34:32,425 | INFO | Fitting SSVI model on 1125 records
# 2026-04-02 10:34:32,426 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:32,427 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:32,428 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:32,625 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.32348442 -0.31733729  1.46600028  0.5       ]
# 2026-04-02 10:34:32,627 | INFO | Fitting SSVI model on 1169 records
# 2026-04-02 10:34:32,651 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:32,651 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:32,655 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:32,793 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.35771575 -0.3386765   1.51304159  0.5       ]
# 2026-04-02 10:34:32,802 | INFO | Fitting SSVI model on 1209 records
# 2026-04-02 10:34:32,803 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:32,805 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:32,809 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:32,981 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30726613 -0.34134562  1.94794677  0.5       ]
# 2026-04-02 10:34:32,984 | INFO | Fitting SSVI model on 1153 records
# 2026-04-02 10:34:32,991 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:32,991 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:32,993 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:33,185 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.39699881 -0.43489826  1.57425333  0.5       ]
# 2026-04-02 10:34:33,193 | INFO | Fitting SSVI model on 1163 records
# 2026-04-02 10:34:33,195 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:33,251 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:33,251 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:33,388 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.37789481 -0.47351168  1.6602022   0.5       ]
# 2026-04-02 10:34:33,402 | INFO | Fitting SSVI model on 1163 records
# 2026-04-02 10:34:33,403 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:33,403 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:33,403 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:33,458 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.42649473 -0.53814484  1.65931919  0.5       ]
# 2026-04-02 10:34:33,462 | INFO | Fitting SSVI model on 1173 records
# 2026-04-02 10:34:33,462 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:33,463 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:33,464 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:33,526 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.41702657 -0.50778388  1.56308727  0.5       ]
# 2026-04-02 10:34:33,531 | INFO | Fitting SSVI model on 1173 records
# 2026-04-02 10:34:33,533 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:33,535 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:33,536 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:33,596 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.41550376 -0.48242368  1.5294777   0.5       ]
# 2026-04-02 10:34:33,602 | INFO | Fitting SSVI model on 1097 records
# 2026-04-02 10:34:33,603 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:33,603 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:33,604 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:33,656 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.37797838 -0.43418762  1.46768381  0.5       ]
# 2026-04-02 10:34:33,660 | INFO | Fitting SSVI model on 1122 records
# 2026-04-02 10:34:33,660 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:33,660 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:33,661 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:33,721 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.32634262 -0.43394758  1.62228759  0.5       ]
# 2026-04-02 10:34:33,725 | INFO | Fitting SSVI model on 1123 records
# 2026-04-02 10:34:33,725 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:33,727 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:33,728 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:33,791 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.33439042 -0.41573737  1.61100797  0.5       ]
# 2026-04-02 10:34:33,797 | INFO | Fitting SSVI model on 1169 records
# 2026-04-02 10:34:33,798 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:33,798 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:33,801 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:33,869 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31220417 -0.41877403  1.66244031  0.5       ]
# 2026-04-02 10:34:33,872 | INFO | Fitting SSVI model on 1188 records
# 2026-04-02 10:34:33,874 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:33,875 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:33,877 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:33,960 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.32684858 -0.42371162  1.61091211  0.5       ]
# 2026-04-02 10:34:33,964 | INFO | Fitting SSVI model on 1109 records
# 2026-04-02 10:34:33,964 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:33,965 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:33,968 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:34,029 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31252525 -0.42286303  1.66191164  0.5       ]
# 2026-04-02 10:34:34,036 | INFO | Fitting SSVI model on 1115 records
# 2026-04-02 10:34:34,037 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:34,037 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:34,038 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:34,112 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31197486 -0.43877382  1.66242878  0.5       ]
# 2026-04-02 10:34:34,119 | INFO | Fitting SSVI model on 1115 records
# 2026-04-02 10:34:34,120 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:34,122 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:34,122 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:34,190 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.33734179 -0.44018805  1.58976879  0.5       ]
# 2026-04-02 10:34:34,196 | INFO | Fitting SSVI model on 1168 records
# 2026-04-02 10:34:34,197 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:34,197 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:34,198 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:34,263 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.32967433 -0.4526678   1.57923206  0.5       ]
# 2026-04-02 10:34:34,269 | INFO | Fitting SSVI model on 1181 records
# 2026-04-02 10:34:34,270 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:34,271 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:34,272 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:34,332 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.3301572  -0.44014097  1.5578528   0.5       ]
# 2026-04-02 10:34:34,340 | INFO | Fitting SSVI model on 1099 records
# 2026-04-02 10:34:34,340 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:34,340 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:34,341 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:34,406 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30771677 -0.43711302  1.59826677  0.5       ]
# 2026-04-02 10:34:34,410 | INFO | Fitting SSVI model on 1099 records
# 2026-04-02 10:34:34,411 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:34,412 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:34,413 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:34,476 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30457145 -0.4291215   1.61307196  0.5       ]
# 2026-04-02 10:34:34,481 | INFO | Fitting SSVI model on 1099 records
# 2026-04-02 10:34:34,484 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:34,484 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:34,486 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:34,549 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.29477154 -0.42743026  1.60917841  0.5       ]
# 2026-04-02 10:34:34,554 | INFO | Fitting SSVI model on 1147 records
# 2026-04-02 10:34:34,556 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:34,557 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:34,558 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:34,642 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.29247091 -0.42844541  1.60377234  0.5       ]
# 2026-04-02 10:34:34,646 | INFO | Fitting SSVI model on 1072 records
# 2026-04-02 10:34:34,647 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:34,648 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:34,653 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:34,728 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.28687449 -0.41938337  1.61733062  0.5       ]
# 2026-04-02 10:34:34,735 | INFO | Fitting SSVI model on 1086 records
# 2026-04-02 10:34:34,735 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:34,736 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:34,737 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:34,803 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.28333777 -0.40282893  1.5321819   0.5       ]
# 2026-04-02 10:34:34,808 | INFO | Fitting SSVI model on 1098 records
# 2026-04-02 10:34:34,808 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:34,809 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:34,810 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:34,875 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.29265544 -0.40008801  1.53655196  0.5       ]
# 2026-04-02 10:34:34,879 | INFO | Fitting SSVI model on 1109 records
# 2026-04-02 10:34:34,880 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:34,881 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:34,884 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:34,939 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30264676 -0.38359899  1.47805601  0.5       ]
# 2026-04-02 10:34:34,943 | INFO | Fitting SSVI model on 1109 records
# 2026-04-02 10:34:34,943 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:34,944 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:34,946 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:35,007 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30466157 -0.39593595  1.45067586  0.5       ]
# 2026-04-02 10:34:35,011 | INFO | Fitting SSVI model on 1023 records
# 2026-04-02 10:34:35,012 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:35,012 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:35,013 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:35,075 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31369865 -0.40149809  1.44640822  0.5       ]
# 2026-04-02 10:34:35,079 | INFO | Fitting SSVI model on 1032 records
# 2026-04-02 10:34:35,080 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:35,080 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:35,080 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:35,141 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.32607035 -0.41358258  1.46038675  0.5       ]
# 2026-04-02 10:34:35,146 | INFO | Fitting SSVI model on 1036 records
# 2026-04-02 10:34:35,146 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:35,146 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:35,147 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:35,298 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31936549 -0.40157677  1.47821815  0.5       ]
# 2026-04-02 10:34:35,309 | INFO | Fitting SSVI model on 1075 records
# 2026-04-02 10:34:35,319 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:35,319 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:35,319 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:35,380 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.32040976 -0.40106831  1.42749962  0.5       ]
# 2026-04-02 10:34:35,387 | INFO | Fitting SSVI model on 1089 records
# 2026-04-02 10:34:35,388 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:35,389 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:35,389 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:35,447 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31221053 -0.40275874  1.4434      0.5       ]
# 2026-04-02 10:34:35,453 | INFO | Fitting SSVI model on 1015 records
# 2026-04-02 10:34:35,454 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:35,454 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:35,455 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:35,512 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31087823 -0.37978833  1.39413733  0.5       ]
# 2026-04-02 10:34:35,519 | INFO | Fitting SSVI model on 1015 records
# 2026-04-02 10:34:35,520 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:35,520 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:35,521 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:35,580 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31104486 -0.37950525  1.37324146  0.5       ]
# 2026-04-02 10:34:35,586 | INFO | Fitting SSVI model on 1015 records
# 2026-04-02 10:34:35,587 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:35,587 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:35,589 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:35,646 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.29839435 -0.35842931  1.42204069  0.5       ]
# 2026-04-02 10:34:35,652 | INFO | Fitting SSVI model on 1054 records
# 2026-04-02 10:34:35,652 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:35,653 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:35,654 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:35,712 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.29838319 -0.33787201  1.43794725  0.5       ]
# 2026-04-02 10:34:35,718 | INFO | Fitting SSVI model on 1096 records
# 2026-04-02 10:34:35,720 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:35,720 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:35,721 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:35,778 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.32142367 -0.39166238  1.23487664  0.5       ]
# 2026-04-02 10:34:35,784 | INFO | Fitting SSVI model on 1023 records
# 2026-04-02 10:34:35,785 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:35,785 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:35,787 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:35,844 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.32206186 -0.3831981   1.24882042  0.5       ]
# 2026-04-02 10:34:35,848 | INFO | Fitting SSVI model on 1031 records
# 2026-04-02 10:34:35,848 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:35,848 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:35,851 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:35,910 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31905086 -0.37730519  1.23413516  0.5       ]
# 2026-04-02 10:34:35,915 | INFO | Fitting SSVI model on 1035 records
# 2026-04-02 10:34:35,918 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:35,919 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:35,919 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:35,974 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31795063 -0.3692938   1.28279128  0.5       ]
# 2026-04-02 10:34:35,978 | INFO | Fitting SSVI model on 1076 records
# 2026-04-02 10:34:35,979 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:35,980 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:35,980 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:36,039 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31503958 -0.39096789  1.24965967  0.5       ]
# 2026-04-02 10:34:36,043 | INFO | Fitting SSVI model on 1086 records
# 2026-04-02 10:34:36,043 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:36,043 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:36,045 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:36,110 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30450318 -0.36173199  1.34423823  0.5       ]
# 2026-04-02 10:34:36,114 | INFO | Fitting SSVI model on 1020 records
# 2026-04-02 10:34:36,115 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:36,116 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:36,119 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:36,177 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30521147 -0.37267613  1.31573112  0.5       ]
# 2026-04-02 10:34:36,181 | INFO | Fitting SSVI model on 1020 records
# 2026-04-02 10:34:36,182 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:36,184 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:36,185 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:36,240 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30088172 -0.35376251  1.40779609  0.5       ]
# 2026-04-02 10:34:36,245 | INFO | Fitting SSVI model on 1024 records
# 2026-04-02 10:34:36,246 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:36,246 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:36,247 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:36,304 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31224522 -0.37991985  1.39988419  0.5       ]
# 2026-04-02 10:34:36,309 | INFO | Fitting SSVI model on 1039 records
# 2026-04-02 10:34:36,309 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:36,310 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:36,310 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:36,364 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.3146437  -0.37116782  1.44666803  0.5       ]
# 2026-04-02 10:34:36,370 | INFO | Fitting SSVI model on 1039 records
# 2026-04-02 10:34:36,371 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:36,372 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:36,372 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:36,432 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31732289 -0.37020604  1.41736334  0.5       ]
# 2026-04-02 10:34:36,438 | INFO | Fitting SSVI model on 978 records
# 2026-04-02 10:34:36,439 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:36,439 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:36,440 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:36,494 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30567245 -0.35103387  1.49486138  0.5       ]
# 2026-04-02 10:34:36,501 | INFO | Fitting SSVI model on 978 records
# 2026-04-02 10:34:36,502 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:36,502 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:36,502 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:36,558 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30786012 -0.36405818  1.42044693  0.5       ]
# 2026-04-02 10:34:36,563 | INFO | Fitting SSVI model on 1033 records
# 2026-04-02 10:34:36,563 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:36,563 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:36,564 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:36,624 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30384698 -0.36453909  1.43531296  0.5       ]
# 2026-04-02 10:34:36,629 | INFO | Fitting SSVI model on 1102 records
# 2026-04-02 10:34:36,629 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:36,630 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:36,631 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:36,692 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30480574 -0.36781875  1.4512384   0.5       ]
# 2026-04-02 10:34:36,697 | INFO | Fitting SSVI model on 1123 records
# 2026-04-02 10:34:36,697 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:36,698 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:36,698 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:36,764 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30368965 -0.37258109  1.41813071  0.5       ]
# 2026-04-02 10:34:36,770 | INFO | Fitting SSVI model on 1062 records
# 2026-04-02 10:34:36,771 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:36,772 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:36,772 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:36,828 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30325141 -0.36875751  1.4246326   0.5       ]
# 2026-04-02 10:34:36,835 | INFO | Fitting SSVI model on 1090 records
# 2026-04-02 10:34:36,835 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:36,835 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:36,836 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:36,897 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30227707 -0.34984557  1.4470121   0.5       ]
# 2026-04-02 10:34:36,904 | INFO | Fitting SSVI model on 1129 records
# 2026-04-02 10:34:36,905 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:36,905 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:36,907 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:37,034 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.3015321  -0.35583491  1.46233545  0.5       ]
# 2026-04-02 10:34:37,054 | INFO | Fitting SSVI model on 1139 records
# 2026-04-02 10:34:37,056 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:37,058 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:37,059 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:37,140 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.29914507 -0.32740424  1.4921148   0.5       ]
# 2026-04-02 10:34:37,144 | INFO | Fitting SSVI model on 1065 records
# 2026-04-02 10:34:37,144 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:37,146 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:37,147 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:37,205 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.29378516 -0.34897863  1.51225823  0.5       ]
# 2026-04-02 10:34:37,209 | INFO | Fitting SSVI model on 1075 records
# 2026-04-02 10:34:37,210 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:37,211 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:37,212 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:37,270 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.29297426 -0.34764958  1.51532848  0.5       ]
# 2026-04-02 10:34:37,274 | INFO | Fitting SSVI model on 1075 records
# 2026-04-02 10:34:37,274 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:37,275 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:37,277 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:37,336 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.28657531 -0.34341276  1.52832188  0.5       ]
# 2026-04-02 10:34:37,340 | INFO | Fitting SSVI model on 1119 records
# 2026-04-02 10:34:37,341 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:37,342 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:37,342 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:37,395 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.28487194 -0.34974946  1.51541861  0.5       ]
# 2026-04-02 10:34:37,401 | INFO | Fitting SSVI model on 1124 records
# 2026-04-02 10:34:37,402 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:37,403 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:37,403 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:37,462 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.27240997 -0.32609436  1.56082107  0.5       ]
# 2026-04-02 10:34:37,469 | INFO | Fitting SSVI model on 1097 records
# 2026-04-02 10:34:37,469 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:37,470 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:37,470 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:37,525 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.27262609 -0.30429319  1.56210764  0.5       ]
# 2026-04-02 10:34:37,529 | INFO | Fitting SSVI model on 1111 records
# 2026-04-02 10:34:37,529 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:37,530 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# ...
# 2026-04-02 10:34:46,811 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.36544714 -0.05976589  1.51650493  0.5       ]
# 2026-04-02 10:34:46,819 | INFO | Fitting SSVI model on 1167 records
# 2026-04-02 10:34:46,820 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:46,820 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:46,820 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:46,939 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.35987482 -0.06092561  1.51754609  0.5       ]
# 2026-04-02 10:34:46,943 | INFO | Fitting SSVI model on 1174 records
# 2026-04-02 10:34:46,944 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:46,944 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:46,945 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:47,001 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.35986127 -0.06729225  1.492481    0.5       ]
# 2026-04-02 10:34:47,007 | INFO | Fitting SSVI model on 1215 records
# 2026-04-02 10:34:47,008 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:47,009 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:47,009 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:47,080 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.35458604 -0.06655079  1.51231471  0.5       ]
# 2026-04-02 10:34:47,087 | INFO | Fitting SSVI model on 1219 records
# 2026-04-02 10:34:47,088 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:47,089 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:47,090 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:47,153 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.34963717 -0.05644834  1.5155103   0.5       ]
# 2026-04-02 10:34:47,157 | INFO | Fitting SSVI model on 1173 records
# 2026-04-02 10:34:47,157 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:47,158 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:47,160 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:47,222 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.34972508 -0.05728719  1.53489098  0.5       ]
# 2026-04-02 10:34:47,226 | INFO | Fitting SSVI model on 1175 records
# 2026-04-02 10:34:47,226 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:47,227 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:47,228 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:47,292 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.34682639 -0.0572528   1.56729145  0.5       ]
# 2026-04-02 10:34:47,297 | INFO | Fitting SSVI model on 1177 records
# 2026-04-02 10:34:47,297 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:47,297 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:47,298 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:47,359 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.34775858 -0.0833839   1.60622914  0.5       ]
# 2026-04-02 10:34:47,363 | INFO | Fitting SSVI model on 1241 records
# 2026-04-02 10:34:47,364 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:47,365 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:47,366 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:47,426 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.34190387 -0.05497056  1.74251558  0.5       ]
# 2026-04-02 10:34:47,431 | INFO | Fitting SSVI model on 1255 records
# 2026-04-02 10:34:47,431 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:47,431 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:47,432 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:47,498 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.34957809 -0.09024577  1.48716696  0.5       ]
# 2026-04-02 10:34:47,505 | INFO | Fitting SSVI model on 1210 records
# 2026-04-02 10:34:47,507 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:47,507 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:47,508 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:47,571 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.34236632 -0.1033586   1.49813419  0.5       ]
# 2026-04-02 10:34:47,577 | INFO | Fitting SSVI model on 1234 records
# 2026-04-02 10:34:47,577 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:47,578 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:47,580 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:47,680 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.33581088 -0.08876982  1.52983572  0.5       ]
# 2026-04-02 10:34:47,691 | INFO | Fitting SSVI model on 1237 records
# 2026-04-02 10:34:47,692 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:47,695 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:47,697 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:47,798 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.32439952 -0.08174491  1.5591129   0.5       ]
# 2026-04-02 10:34:47,807 | INFO | Fitting SSVI model on 1276 records
# 2026-04-02 10:34:47,808 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:47,808 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:47,810 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:47,895 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.32572463 -0.07901329  1.59653894  0.5       ]
# 2026-04-02 10:34:47,902 | INFO | Fitting SSVI model on 1280 records
# 2026-04-02 10:34:47,902 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:47,903 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:47,903 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:47,961 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.32358394 -0.08630523  1.58513157  0.5       ]
# 2026-04-02 10:34:47,965 | INFO | Fitting SSVI model on 1189 records
# 2026-04-02 10:34:47,968 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:47,968 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:47,971 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:48,137 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31403366 -0.08106392  1.66905026  0.5       ]
# 2026-04-02 10:34:48,144 | INFO | Fitting SSVI model on 1195 records
# 2026-04-02 10:34:48,144 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:48,144 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:48,144 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:48,243 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31685456 -0.09424541  1.6221446   0.5       ]
# 2026-04-02 10:34:48,247 | INFO | Fitting SSVI model on 1195 records
# 2026-04-02 10:34:48,248 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:48,249 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:48,252 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:48,309 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31721615 -0.11815937  1.58532819  0.5       ]
# 2026-04-02 10:34:48,313 | INFO | Fitting SSVI model on 1239 records
# 2026-04-02 10:34:48,313 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:48,314 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:48,315 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:48,377 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.3168925  -0.09302909  1.61513378  0.5       ]
# 2026-04-02 10:34:48,381 | INFO | Fitting SSVI model on 1239 records
# 2026-04-02 10:34:48,381 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:48,383 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:48,385 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:48,448 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.3108732  -0.08960073  1.60657656  0.5       ]
# 2026-04-02 10:34:48,455 | INFO | Fitting SSVI model on 1155 records
# 2026-04-02 10:34:48,456 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:48,456 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:48,457 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:48,507 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30150199 -0.08637756  1.75204998  0.5       ]
# 2026-04-02 10:34:48,511 | INFO | Fitting SSVI model on 1155 records
# 2026-04-02 10:34:48,512 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:48,512 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:48,513 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:48,579 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31156033 -0.0810701   1.62580471  0.5       ]
# 2026-04-02 10:34:48,586 | INFO | Fitting SSVI model on 1155 records
# 2026-04-02 10:34:48,586 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:48,586 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:48,587 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:48,643 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30796885 -0.07647348  1.69747298  0.5       ]
# 2026-04-02 10:34:48,647 | INFO | Fitting SSVI model on 1204 records
# 2026-04-02 10:34:48,647 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:48,647 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:48,648 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:48,715 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31040401 -0.0901691   1.60073081  0.5       ]
# 2026-04-02 10:34:48,724 | INFO | Fitting SSVI model on 1204 records
# 2026-04-02 10:34:48,724 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:48,725 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:48,726 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:48,798 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31159235 -0.0829493   1.56799302  0.5       ]
# 2026-04-02 10:34:48,807 | INFO | Fitting SSVI model on 1063 records
# 2026-04-02 10:34:48,807 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:48,808 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:48,809 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:48,865 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30036102 -0.0660008   1.61106279  0.5       ]
# 2026-04-02 10:34:48,873 | INFO | Fitting SSVI model on 1063 records
# 2026-04-02 10:34:48,876 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:48,877 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:48,877 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:48,940 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30119569 -0.058459    1.56814282  0.5       ]
# 2026-04-02 10:34:48,945 | INFO | Fitting SSVI model on 1100 records
# 2026-04-02 10:34:48,946 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:48,946 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:48,948 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:49,022 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.30462329 -0.05477566  1.56497615  0.5       ]
# 2026-04-02 10:34:49,028 | INFO | Fitting SSVI model on 1042 records
# 2026-04-02 10:34:49,028 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:49,029 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:49,030 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:49,093 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.32076445 -0.04597489  1.63352712  0.5       ]
# 2026-04-02 10:34:49,097 | INFO | Fitting SSVI model on 1045 records
# 2026-04-02 10:34:49,098 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:49,099 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:49,102 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:49,162 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.32555825 -0.04122157  1.56955004  0.5       ]
# 2026-04-02 10:34:49,168 | INFO | Fitting SSVI model on 1045 records
# 2026-04-02 10:34:49,168 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:49,170 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:49,171 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:49,232 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.32868614 -0.0414343   1.51442318  0.5       ]
# 2026-04-02 10:34:49,238 | INFO | Fitting SSVI model on 1107 records
# 2026-04-02 10:34:49,239 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:49,239 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:49,240 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:49,370 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.32712089 -0.05484414  1.51127605  0.5       ]
# 2026-04-02 10:34:49,388 | INFO | Fitting SSVI model on 1115 records
# 2026-04-02 10:34:49,388 | INFO | Initial guess: (0.2, -0.4, 0.2, 0.4)
# 2026-04-02 10:34:49,388 | INFO | Parameter bounds: [(1e-05, None), (-0.999, 0.999), (1e-06, 5.0), (1e-06, 0.5)]
# 2026-04-02 10:34:49,395 | INFO | Solver: L-BFGS-B
# 2026-04-02 10:34:49,478 | INFO | Successfully fitted SSVI Model. Found the following Parameters [ 0.31267328 -0.04280556  1.77454038  0.5       ]
#     spot  strike expiration    delta    gamma     vega    theta      rho  \
# 0  299.8   200.0 2020-01-10  1.00000  0.00000  0.00000 -0.00004  0.02788
# 1  299.8   205.0 2020-01-10  0.99821  0.00015  0.00173 -0.01508  0.02786
# 2  299.8   210.0 2020-01-10  0.99075  0.00057  0.00840 -0.08789  0.02864
# 3  299.8   215.0 2020-01-10  0.99618  0.00028  0.00362 -0.03106  0.02948
# 4  299.8   220.0 2020-01-10  1.00000  0.00000  0.00000 -0.00048  0.03037
#
#    implied_volatility    bid  ...  call_put          option_id     mid ticker  \
# 0             0.00000  99.15  ...         C  AAPL 20200110C200  99.550   AAPL
# 1             1.13225  94.56  ...         C  AAPL 20200110C205  94.805   AAPL
# 2             1.32704  89.65  ...         C  AAPL 20200110C210  89.925   AAPL
# 3             1.08562  84.70  ...         C  AAPL 20200110C215  84.825   AAPL
# 4             0.00000  79.34  ...         C  AAPL 20200110C220  79.695   AAPL
#
#         date day_to_expiration moneyness  risk_free_rate     forward  \
# 0 2020-01-06                 4  0.667111          0.0154  299.850566
# 1 2020-01-06                 4  0.683789          0.0154  299.850566
# 2 2020-01-06                 4  0.700467          0.0154  299.850566
# 3 2020-01-06                 4  0.717145          0.0154  299.850566
# 4 2020-01-06                 4  0.733823          0.0154  299.850566
#
#    implied_volatility_SSVI
# 0                 0.790837
# 1                 0.767685
# 2                 0.744400
# 3                 0.720942
# 4                 0.697268
#
# [5 rows x 22 columns]

# %%
df_selected_90P = select_options(
    df_options_calibrated,
    call_or_put="P",
    strike_col="moneyness",
    strike_target=0.9,
    day_to_expiry_target=40,
)
df_selected_110C = select_options(
    df_options_calibrated,
    call_or_put="C",
    strike_col="moneyness",
    strike_target=1.1,
    day_to_expiry_target=40,
)
df_selected_100C = select_options(
    df_options_calibrated,
    call_or_put="C",
    strike_col="moneyness",
    strike_target=1.0,
    day_to_expiry_target=40,
)

# %%
skew_2 = (
    df_selected_90P.set_index("date")[["implied_volatility"]] - df_selected_110C.set_index("date")[["implied_volatility"]]
) / df_selected_100C.set_index("date")[["implied_volatility"]]
skew_1 = df_selected_90P.set_index("date")[["implied_volatility"]] - df_selected_110C.set_index("date")[["implied_volatility"]]


ax = skew_2.plot(grid=True, figsize=(20, 8))
skew_1.plot(grid=True, figsize=(20, 8), ax=ax)
# Out:
# <Axes: xlabel='date'>

# %%
df_selected_100C.set_index("date")[["implied_volatility_SSVI", "implied_volatility"]].plot(grid=True, figsize=(20, 8))
# Out:
# <Axes: xlabel='date'>
